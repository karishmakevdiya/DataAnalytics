# %%
type(-12 + 100)
# Out:
# int

# %%
type(-12 + 100.53)
# Out:
# float

# %%
type(-12 + 3j)
# Out:
# complex

# %%
#Boolean
type(True)
# Out:
# bool

# %%
-12 < 15
# Out:
# True

# %%
#strigs

'Single Quote'
# Out:
# 'Single Quote'

# %%
"Double Quote"
# Out:
# 'Double Quote'

# %%
multiine = """ 
the icecream
is 
good

"""

# %%
print(multiine)
# Out:
#
# the icecream
# is
# good

# %%
"I've always wanted to eat a icecream."
type(multiine)
# Out:
# str

# %%
a = "hello world"
print(a[6])
print(a[-3])
print(a[2 : 5])
# Out:
# w
# r
# llo

# %%
a*3
# Out:
# 'hello worldhello worldhello world'

# %%
a +a
# Out:
# 'hello worldhello world'

# %%
#List
[1, 2, 3, 4]
# Out:
# [1, 2, 3, 4]

# %%
['cookie Dough', 'chocolate']
# Out:
# ['cookie Dough', 'chocolate']

# %%
['vanila', 3, ['scoops','spoon'], True]
# Out:
# ['vanila', 3, ['scoops', 'spoon'], True]

# %%
ice_cream = ['cookie Dough', 'chocolate']

ice_cream.append('salte Caramel')
ice_cream
# Out:
# ['cookie Dough', 'chocolate', 'salte Caramel']

# %%
ice_cream[0] = 'butter pecan'
ice_cream
# Out:
# ['butter pecan', 'chocolate', 'salte Caramel']

# %%
nest_list = ['vanila', 3, ['scoops','spoon'], True]

nest_list[2]

nest_list[2][1]
# Out:
# 'spoon'

# %%
#Tuple

tuple_scoops = (1,2,3,2,1)
type(tuple_scoops)
# Out:
# tuple

# %%
tuple_scoops.appent(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 tuple_scoops.appent(3)
#
# AttributeError: 'tuple' object has no attribute 'appent'

# %%
#sets

daily_pints = {1,2,3}
type(daily_pints)
# Out:
# set

# %%
daily_pints_log = {1,2,31,2,3,0,1,4,3,5,6,2}
print(daily_pints_log)
# Out:
# {0, 1, 2, 3, 4, 5, 6, 31}

# %%
wifes_daily_pints_log = {1,2,5,4,7,6,9,0,55}

# %%
print(daily_pints_log  | wifes_daily_pints_log)
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7, 9, 55, 31}

# %%
print(daily_pints_log  & wifes_daily_pints_log)
# Out:
# {0, 1, 2, 4, 5, 6}

# %%
print(daily_pints_log  - wifes_daily_pints_log)
# Out:
# {3, 31}

# %%
print(daily_pints_log ^ wifes_daily_pints_log)
# Out:
# {3, 7, 9, 55, 31}

# %%
#Dictionaries

#key Values Pair

dict_cream = {
    'name' : 'xyz',
    'weekly intake' : 5,
    'favourite ice cream' : ['Vanila', 'Chocolat']
}
type(dict_cream)
# Out:
# dict

# %%
print(dict_cream)
# Out:
# {'name': 'xyz', 'weekly intake': 5, 'favourite ice cream': ['Vanila', 'Chocolat']}

# %%
dict_cream.values()
# Out:
# dict_values(['xyz', 5, ['Vanila', 'Chocolat']])

# %%
dict_cream.keys()
# Out:
# dict_keys(['name', 'weekly intake', 'favourite ice cream'])

# %%
dict_cream.items()
# Out:
# dict_items([('name', 'xyz'), ('weekly intake', 5), ('favourite ice cream', ['Vanila', 'Chocolat'])])

# %%
dict_cream[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 dict_cream[0]
#
# KeyError: 0

# %%
dict_cream['name']
# Out:
# 'xyz'

# %%
dict_cream['name'] = 'ABC'
dict_cream['name']
# Out:
# 'ABC'

# %%
dict_cream.update({'name': 'xyz', 'weekly intake': 10, 'weight': 300})
print(dict_cream)
# Out:
# {'name': 'xyz', 'weekly intake': 10, 'favourite ice cream': ['Vanila', 'Chocolat'], 'weight': 300}

# %%
del dict_cream['weight']

print(dict_cream)
# Out:
# {'name': 'xyz', 'weekly intake': 10, 'favourite ice cream': ['Vanila', 'Chocolat']}
